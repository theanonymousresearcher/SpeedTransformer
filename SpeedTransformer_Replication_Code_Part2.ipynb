# %% [markdown]
# # Replication Code for "Predicting Human Mobility Using Dense Smartphone GPS Trajectories and Transformer Models"

# %% [markdown]
# ## Disclaimer on Exact Reproducibility Across GPU Hardware
#
# Even when every source of randomness is fully seeded (Python random, NumPy, PyTorch, data‐loader workers), and the exact same library binaries (PyTorch 2.4.1+cu121, CUDA 12.1, cuDNN 9.1, NumPy 1.23.5, etc.) are installed, bit‐for‐bit identical results can only be guaranteed on the same GPU architecture. For example, our primary experiments were run on an NVIDIA RTX A5000 (Driver 560.35.05, CUDA 12.6), and the deterministic cuDNN kernels selected on that card produce a very specific floating‐point rounding path. Colab typically provides T4, P100, or V100 GPUs, which—even under a “deterministic” build of cuDNN—invoke different optimized kernels and may accumulate minute floating‐point differences over hundreds of weight updates. As a result, anyone who is running the same code on Colab GPUs should expect functionally equivalent behavior (identical losses up to ≈1e-6), but they will not see precisely the same final weights or epoch‐by‐epoch outputs unless they use an RTX A5000 (or another card with identical compute capability and driver).

# %% [markdown]
# ## Setting up environment

# %%
# Uninstall pre-installed torch, torchvision, torchaudio, numpy
# !pip uninstall -y torch torchvision torchaudio numpy
# Out:
# Found existing installation: torch 2.8.0+cu126
# Uninstalling torch-2.8.0+cu126:
#   Successfully uninstalled torch-2.8.0+cu126
# Found existing installation: torchvision 0.23.0+cu126
# Uninstalling torchvision-0.23.0+cu126:
#   Successfully uninstalled torchvision-0.23.0+cu126
# Found existing installation: torchaudio 2.8.0+cu126
# Uninstalling torchaudio-2.8.0+cu126:
#   Successfully uninstalled torchaudio-2.8.0+cu126
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2

# %%
# Install torch 2.4.1+cu121, torchvision 0.19.1+cu121 and torchaudio 2.4.1+cu121
# !pip install \
    torch==2.4.1+cu121 \
    torchvision==0.19.1+cu121 \
    torchaudio==2.4.1+cu121 \
    --extra-index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# Collecting torch==2.4.1+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.4.1%2Bcu121-cp312-cp312-linux_x86_64.whl (798.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 1.8 MB/s eta 0:00:00
# Collecting torchvision==0.19.1+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.19.1%2Bcu121-cp312-cp312-linux_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 117.5 MB/s eta 0:00:00
# Collecting torchaudio==2.4.1+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torchaudio-2.4.1%2Bcu121-cp312-cp312-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 88.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (2025.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.4.1+cu121) (75.2.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 88.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 107.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.6 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.7 MB/s eta 0:00:00
# Collecting triton==3.0.0 (from torch==2.4.1+cu121)
#   Downloading https://download.pytorch.org/whl/triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.8 MB/s eta 0:00:00
# Collecting numpy (from torchvision==0.19.1+cu121)
#   Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.19.1+cu121) (11.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1+cu121) (12.6.85)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.4.1+cu121) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.4.1+cu121) (1.3.0)
# Downloading numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 97.4 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# Successfully installed numpy-2.3.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 torch-2.4.1+cu121 torchaudio-2.4.1+cu121 torchvision-0.19.1+cu121 triton-3.0.0

# %% [markdown]
# Import modules PyTorch and Numpy, which will be used in model training.

# %%
import torch
import numpy as np
print("Colab PyTorch:", torch.__version__, "CUDA:", torch.version.cuda, "cuDNN:", torch.backends.cudnn.version())
print("NumPy:", np.__version__)
# Out:
# Colab PyTorch: 2.4.1+cu121 CUDA: 12.1 cuDNN: 90100
# NumPy: 2.3.4

# %% [markdown]
# ## Downloading Replication Code and Data

# %% [markdown]
# This section downloads the published codebase (_SpeedTransformer_) and the three pre‑processed datasets (_MOBIS_, _GeoLife_, and _Miniprogram_) exactly as referenced in **Section “Data and Codes Availability”**.
# The repository zip is fetched from Zenodo and unzipped into the Colab working directory.
# The subsequent cell creates a `data/` folder where the CSV files are stored so that the training scripts can locate them via the relative paths used throughout the notebook.

# %%
# !wget https://zenodo.org/records/17429944/files/SpeedTransformer.zip -O /content/SpeedTransformer.zip
# !unzip /content/SpeedTransformer.zip
# Out:
# --2025-10-26 20:59:33--  https://zenodo.org/records/17429944/files/SpeedTransformer.zip
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25755626 (25M) [application/octet-stream]
# Saving to: ‘/content/SpeedTransformer.zip’
#
# /content/SpeedTrans 100%[===================>]  24.56M  8.78MB/s    in 2.8s
#
# 2025-10-26 20:59:36 (8.78 MB/s) - ‘/content/SpeedTransformer.zip’ saved [25755626/25755626]
#
# Archive:  /content/SpeedTransformer.zip
#    creating: SpeedTransformer/
#   inflating: __MACOSX/._SpeedTransformer
#   inflating: SpeedTransformer/SpeedTransformer.ipynb
#   inflating: __MACOSX/SpeedTransformer/._SpeedTransformer.ipynb
#   inflating: SpeedTransformer/.DS_Store
#   inflating: __MACOSX/SpeedTransformer/._.DS_Store
#    creating: SpeedTransformer/models/
#   inflating: __MACOSX/SpeedTransformer/._models
#   inflating: SpeedTransformer/README.md
#   inflating: __MACOSX/SpeedTransformer/._README.md
#   inflating: SpeedTransformer/.gitignore
#   inflating: __MACOSX/SpeedTransformer/._.gitignore
#    creating: SpeedTransformer/data/
#   inflating: __MACOSX/SpeedTransformer/._data
#    creating: SpeedTransformer/models/transformer/
#   inflating: __MACOSX/SpeedTransformer/models/._transformer
#    creating: SpeedTransformer/models/rule_based/
#   inflating: __MACOSX/SpeedTransformer/models/._rule_based
#    creating: SpeedTransformer/models/replication/
#   inflating: __MACOSX/SpeedTransformer/models/._replication
#   inflating: SpeedTransformer/models/run_speedtransformer_rf_visualize_computation.py
#   inflating: __MACOSX/SpeedTransformer/models/._run_speedtransformer_rf_visualize_computation.py
#    creating: SpeedTransformer/models/lstm/
#   inflating: __MACOSX/SpeedTransformer/models/._lstm
#   inflating: SpeedTransformer/data/carbonClever.py
#   inflating: __MACOSX/SpeedTransformer/data/._carbonClever.py
#   inflating: SpeedTransformer/data/extract_speed_geolife.py
#   inflating: __MACOSX/SpeedTransformer/data/._extract_speed_geolife.py
#   inflating: SpeedTransformer/data/describe_speed.py
#   inflating: __MACOSX/SpeedTransformer/data/._describe_speed.py
#   inflating: SpeedTransformer/data/process_geolife.py
#   inflating: __MACOSX/SpeedTransformer/data/._process_geolife.py
#   inflating: SpeedTransformer/models/transformer/model_utils.py
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._model_utils.py
#    creating: SpeedTransformer/models/transformer/experiments/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._experiments
#   inflating: SpeedTransformer/models/transformer/finetune_miniprogram.sh
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._finetune_miniprogram.sh
#   inflating: SpeedTransformer/models/transformer/finetune.sh
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._finetune.sh
#   inflating: SpeedTransformer/models/transformer/test.py
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._test.py
#   inflating: SpeedTransformer/models/transformer/data_utils.py
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._data_utils.py
#   inflating: SpeedTransformer/models/transformer/train.py
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._train.py
#   inflating: SpeedTransformer/models/transformer/ws_sweep.sh
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._ws_sweep.sh
#   inflating: SpeedTransformer/models/transformer/run_sweep.sh
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._run_sweep.sh
#   inflating: SpeedTransformer/models/transformer/finetune.py
#   inflating: __MACOSX/SpeedTransformer/models/transformer/._finetune.py
#   inflating: SpeedTransformer/models/rule_based/rule_baseline.py
#   inflating: __MACOSX/SpeedTransformer/models/rule_based/._rule_baseline.py
#   inflating: SpeedTransformer/models/rule_based/label_encoder.joblib
#   inflating: __MACOSX/SpeedTransformer/models/rule_based/._label_encoder.joblib
#   inflating: SpeedTransformer/models/replication/run_miniprogram_finetune_experiments.sh
#   inflating: __MACOSX/SpeedTransformer/models/replication/._run_miniprogram_finetune_experiments.sh
#   inflating: SpeedTransformer/models/replication/FigC1_combined_per_class_f1.png
#   inflating: __MACOSX/SpeedTransformer/models/replication/._FigC1_combined_per_class_f1.png
#   inflating: SpeedTransformer/models/replication/run_training_experiments.sh
#   inflating: __MACOSX/SpeedTransformer/models/replication/._run_training_experiments.sh
#   inflating: SpeedTransformer/models/replication/experiment_summary.csv
#   inflating: __MACOSX/SpeedTransformer/models/replication/._experiment_summary.csv
#   inflating: SpeedTransformer/models/replication/run_gl_finetune_experiments.sh
#   inflating: __MACOSX/SpeedTransformer/models/replication/._run_gl_finetune_experiments.sh
#   inflating: SpeedTransformer/models/replication/FigF1_geolife_window_size_accuracy.png
#   inflating: __MACOSX/SpeedTransformer/models/replication/._FigF1_geolife_window_size_accuracy.png
#   inflating: SpeedTransformer/models/replication/run_gl_lowshot_finetune_experiments.sh
#   inflating: __MACOSX/SpeedTransformer/models/replication/._run_gl_lowshot_finetune_experiments.sh
#   inflating: SpeedTransformer/models/replication/Fig3_original_datasets_val_comparison.png
#   inflating: __MACOSX/SpeedTransformer/models/replication/._Fig3_original_datasets_val_comparison.png
#   inflating: SpeedTransformer/models/replication/experiment_tables.py
#   inflating: __MACOSX/SpeedTransformer/models/replication/._experiment_tables.py
#   inflating: SpeedTransformer/models/replication/metrics_gen.py
#   inflating: __MACOSX/SpeedTransformer/models/replication/._metrics_gen.py
#   inflating: SpeedTransformer/models/replication/run_window_sweep_experiments.sh
#   inflating: __MACOSX/SpeedTransformer/models/replication/._run_window_sweep_experiments.sh
#   inflating: SpeedTransformer/models/replication/Fig4_geolife_mobis_model_f1.png
#   inflating: __MACOSX/SpeedTransformer/models/replication/._Fig4_geolife_mobis_model_f1.png
#   inflating: SpeedTransformer/models/lstm/models.py
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._models.py
#    creating: SpeedTransformer/models/lstm/experiments/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._experiments
#   inflating: SpeedTransformer/models/lstm/finetune_miniprogram.sh
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._finetune_miniprogram.sh
#   inflating: SpeedTransformer/models/lstm/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._lstm.log
#   inflating: SpeedTransformer/models/lstm/finetune.sh
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._finetune.sh
#   inflating: SpeedTransformer/models/lstm/scaler.joblib
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._scaler.joblib
#   inflating: SpeedTransformer/models/lstm/label_encoder.joblib
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._label_encoder.joblib
#   inflating: SpeedTransformer/models/lstm/best_model.pth
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._best_model.pth
#   inflating: SpeedTransformer/models/lstm/data_utils.py
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._data_utils.py
#   inflating: SpeedTransformer/models/lstm/ws_sweep.sh
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._ws_sweep.sh
#   inflating: SpeedTransformer/models/lstm/trainer.py
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._trainer.py
#   inflating: SpeedTransformer/models/lstm/run_sweep.sh
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._run_sweep.sh
#   inflating: SpeedTransformer/models/lstm/lstm.py
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._lstm.py
#   inflating: SpeedTransformer/models/lstm/finetune.py
#   inflating: __MACOSX/SpeedTransformer/models/lstm/._finetune.py
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._finetune_sweeps
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._miniprogram_finetune
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._geolife_transformer_sweeps
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._mobis_transformer_sweeps
#    creating: SpeedTransformer/models/transformer/experiments/finetune_lowshot/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._finetune_lowshot
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/._geolife_window_sweeps
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/._finetune_sweeps
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/._miniprogram_finetune
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/._mobis_lstm_sweeps
#    creating: SpeedTransformer/models/lstm/experiments/finetune_lowshot/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/._finetune_lowshot
#    creating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/._geolife_lstm_sweeps
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_reinit_last/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_reinit_last
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_freeze_first_half/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_freeze_first_half
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup100_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup100_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup0_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup0_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr5e-5_warmup500_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr5e-5_warmup500_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup100_grad_unfreeze/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup100_grad_unfreeze
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr1e-4_warmup500_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr1e-4_warmup500_full
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup500_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup500_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/finetune_sweeps/lr2e-4_warmup0_full/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_sweeps/._lr2e-4_warmup0_full
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup50_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup50_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/final_40pct_251trips_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._final_40pct_251trips_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup50_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup50_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup50_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup50_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup50_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup50_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/final_20pct_125trips_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._final_20pct_125trips_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup50_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup50_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup50_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup50_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/final_15pct_94trips_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._final_15pct_94trips_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup50_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup50_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup100_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup100_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup50_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup50_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/final_50pct_313trips_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._final_50pct_313trips_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup100_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup100_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup0_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup0_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup100_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup100_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup50_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup50_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup0_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup0_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup50_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup50_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/final_30pct_189trips_lr5e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._final_30pct_189trips_lr5e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup50_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup50_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup0_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup0_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup100_none/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup100_none
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr1e-4_warmup100_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr1e-4_warmup100_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr2e-4_warmup50_freeze_feedforward/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr2e-4_warmup50_freeze_feedforward
#    creating: SpeedTransformer/models/transformer/experiments/miniprogram_finetune/tune_lr5e-4_warmup100_freeze_embeddings/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/miniprogram_finetune/._tune_lr5e-4_warmup100_freeze_embeddings
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs512_h8_d128_kv4_do0.2/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs512_h8_d128_kv4_do0.2
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr1e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr1e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs512_h12_d192_kv6_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs512_h12_d192_kv6_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs512_h8_d256_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs512_h8_d256_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs1024_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs1024_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr2e-4_bs512_h8_d128_kv2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr2e-4_bs512_h8_d128_kv2_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/lr3e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_transformer_sweeps/._lr3e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr3e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs512_h8_d128_kv2_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs512_h8_d256_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs512_h12_d192_kv6_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr2e-4_bs512_h8_d128_kv4_do0.2
#    creating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/._mobis_lr1e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/finetune_lowshot/train100_lr2e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_lowshot/._train100_lr2e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/finetune_lowshot/train200_lr2e-4_warmup0_freeze_attention/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/finetune_lowshot/._train200_lr2e-4_warmup0_freeze_attention
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/._geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-4_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-4_h64
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-3_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-3_h256
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-3_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-3_h64
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-3_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-3_h128
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr5e-4_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr5e-4_h64
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr1e-4_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr1e-4_h256
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/finetune_sweeps/lstm_lr5e-4_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_sweeps/._lstm_lr5e-4_h256
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-3_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-3_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr5e-4_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr5e-4_h64
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-3_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-3_h256
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/final_40pct_251trips_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._final_40pct_251trips_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-3_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-3_h64
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-4_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-4_h256
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/final_50pct_313trips_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._final_50pct_313trips_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/final_15pct_94trips_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._final_15pct_94trips_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-4_h64/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-4_h64
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr1e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr1e-4_h128
#   inflating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/summary.txt
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._summary.txt
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr5e-4_h256/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr5e-4_h256
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/tune_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._tune_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/final_30pct_189trips_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._final_30pct_189trips_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/miniprogram_finetune/final_20pct_125trips_lr5e-4_h128/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/miniprogram_finetune/._final_20pct_125trips_lr5e-4_h128
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr1e-3_bs64_h256_l2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr1e-3_bs64_h256_l2_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr1e-3_bs64_h128_l3_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr1e-3_bs64_h128_l3_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr1e-3_bs64_h128_l2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr1e-3_bs64_h128_l2_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr5e-4_bs64_h128_l2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr5e-4_bs64_h128_l2_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr5e-4_bs128_h256_l3_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr5e-4_bs128_h256_l3_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr1e-3_bs128_h128_l2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr1e-3_bs128_h128_l2_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr1e-3_bs64_h128_l2_do0.2/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr1e-3_bs64_h128_l2_do0.2
#    creating: SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr2e-3_bs64_h128_l2_do0.1/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/._mobis_lr2e-3_bs64_h128_l2_do0.1
#    creating: SpeedTransformer/models/lstm/experiments/finetune_lowshot/train200_lr5e-5_bs128_do0.3/
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_lowshot/._train200_lr5e-5_bs128_do0.3
#    creating: SpeedTransformer/models/lstm/experiments/finetune_lowshot/train100_lr5e-5_bs128_do0.3/
# ...
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/mobis_lstm_sweeps/mobis_lr2e-3_bs64_h128_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/finetune_lowshot/train200_lr5e-5_bs128_do0.3/finetune.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_lowshot/train200_lr5e-5_bs128_do0.3/._finetune.log
#   inflating: SpeedTransformer/models/lstm/experiments/finetune_lowshot/train100_lr5e-5_bs128_do0.3/finetune.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/finetune_lowshot/train100_lr5e-5_bs128_do0.3/._finetune.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h256_l2_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h256_l2_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h256_l2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h256_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs128_h256_l3_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs128_h256_l3_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs128_h256_l3_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs128_h256_l3_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs128_h128_l2_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs128_h128_l2_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs128_h128_l2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs128_h128_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l3_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l3_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l3_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l3_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs64_h128_l2_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs64_h128_l2_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs64_h128_l2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr5e-4_bs64_h128_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.2/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.2/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.2/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr1e-3_bs64_h128_l2_do0.2/._train.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr2e-3_bs64_h128_l2_do0.1/lstm.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr2e-3_bs64_h128_l2_do0.1/._lstm.log
#   inflating: SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr2e-3_bs64_h128_l2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/lstm/experiments/geolife_lstm_sweeps/geolife_lr2e-3_bs64_h128_l2_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/mobis_lr3e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/mobis_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/mobis_lr2e-4_bs512_h8_d128_kv2_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/mobis_lr2e-4_bs512_h8_d256_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/mobis_lr2e-4_bs512_h12_d192_kv6_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/mobis_lr2e-4_bs1024_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/mobis_lr2e-4_bs512_h8_d128_kv4_do0.2/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/mobis_transformer_sweeps/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/mobis_lr1e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws20_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws500_lr2e-4_bs256_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws300_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws50_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/geolife_ws400_lr2e-4_bs256_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws100_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/confusion_matrix.png
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/._confusion_matrix.png
#   inflating: SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/train.log
#   inflating: __MACOSX/SpeedTransformer/models/transformer/experiments/geolife_window_sweeps/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/geolife_ws200_lr2e-4_bs512_h8_d128_kv4_do0.1/._train.log

# %%
# Download CSV files into the data/ directory
# !wget -O /content/SpeedTransformer/data/mobis_processed.csv https://zenodo.org/record/17429944/files/mobis_processed.csv
# !wget -O /content/SpeedTransformer/data/geolife_processed.csv https://zenodo.org/record/17429944/files/geolife_processed.csv
# !wget -O /content/SpeedTransformer/data/miniprogram_balanced.csv https://zenodo.org/record/17429944/files/miniprogram_balanced.csv
# Out:
# --2025-10-26 20:59:43--  https://zenodo.org/record/17429944/files/mobis_processed.csv
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/17429944/files/mobis_processed.csv [following]
# --2025-10-26 20:59:44--  https://zenodo.org/records/17429944/files/mobis_processed.csv
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 31273348118 (29G) [text/plain]
# Saving to: ‘/content/SpeedTransformer/data/mobis_processed.csv’
#
# nt/SpeedTransformer  82%[===============>    ]  24.03G  13.5MB/s    eta 6m 26s ^C
# --2025-10-26 21:30:08--  https://zenodo.org/record/17429944/files/geolife_processed.csv
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/17429944/files/geolife_processed.csv [following]
# --2025-10-26 21:30:09--  https://zenodo.org/records/17429944/files/geolife_processed.csv
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 273678345 (261M) [text/plain]
# Saving to: ‘/content/SpeedTransformer/data/geolife_processed.csv’
#
#                      78%[==============>     ] 205.59M  17.5MB/s    eta 4s     ^C
# --2025-10-26 21:30:23--  https://zenodo.org/record/17429944/files/miniprogram_balanced.csv
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/17429944/files/miniprogram_balanced.csv [following]
# --2025-10-26 21:30:24--  https://zenodo.org/records/17429944/files/miniprogram_balanced.csv
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9495604 (9.1M) [text/plain]
# Saving to: ‘/content/SpeedTransformer/data/miniprogram_balanced.csv’
#
# /content/SpeedTrans 100%[===================>]   9.06M  4.67MB/s    in 1.9s
#
# 2025-10-26 21:30:26 (4.67 MB/s) - ‘/content/SpeedTransformer/data/miniprogram_balanced.csv’ saved [9495604/9495604]

# %% [markdown]
# Organize the data files.

# %%
# !mv /content/SpeedTransformer /content/A-SpeedTransformer

# %% [markdown]
# Move data to a Google Cloud Storage. Import it later after switching to a GPU node later.

# %%
# === Configuration ===
PROJECT_ID = "osmandgdelt" # switch to your project_id
BUCKET_NAME = "speed_transformer"  # switch to your bucket name
BUCKET_LOCATION = "us-west1"          # switch to a region close to you
LOCAL_DIR = "/content/A-SpeedTransformer" # your local source directory
GCS_PREFIX = "speed_transformer"  # folder-like prefix in the bucket

# === Install and authenticate ===
# %pip -q install -U google-cloud-storage gcsfs

from google.colab import auth
auth.authenticate_user()  # login to your Google account
print("Authenticated.")

# === Create bucket if it doesn't exist ===
import google.cloud.storage as gcs

client = gcs.Client(project=PROJECT_ID)
existing = [b.name for b in client.list_buckets() if b.name == BUCKET_NAME]
if not existing:
    bucket = client.bucket(BUCKET_NAME)
    bucket.storage_class = "STANDARD"
    client.create_bucket(bucket, location=BUCKET_LOCATION)
    print(f"Created bucket: gs://{BUCKET_NAME}/ in {BUCKET_LOCATION}")
else:
    print(f"Bucket exists: gs://{BUCKET_NAME}/")

# === (Option 1) Fast, robust upload with gsutil (recommended for large trees) ===
# Preserves filenames exactly; parallelized and resumable.
import subprocess, shlex
cmd = f'gsutil -m rsync -r -d "{LOCAL_DIR}" "gs://{BUCKET_NAME}/{GCS_PREFIX}"'
print(cmd)
subprocess.check_call(shlex.split(cmd))
print("Upload complete via gsutil rsync.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 9.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-aiplatform 1.121.0 requires google-cloud-storage<3.0.0,>=1.32.0, but you have google-cloud-storage 3.4.1 which is incompatible.
# google-adk 1.16.0 requires google-cloud-storage<3.0.0,>=2.18.0, but you have google-cloud-storage 3.4.1 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# Authenticated.
# Bucket exists: gs://speed_transformer/
# gsutil -m rsync -r -d "/content/A-SpeedTransformer" "gs://speed_transformer/speed_transformer"
# Upload complete via gsutil rsync.

# %% [markdown]
# Re-import the data from Google Cloud Storage

# %%
# === Configuration ===
PROJECT_ID = "osmandgdelt"
BUCKET_NAME = "speed_transformer"           # your existing bucket
GCS_PREFIX = "speed_transformer"            # folder prefix in GCS
LOCAL_DIR = "/content/A-SpeedTransformer"   # local target directory (important!)

# === Install and authenticate ===
# %pip -q install -U google-cloud-storage gcsfs

from google.colab import auth
auth.authenticate_user()  # log in again after switching runtime
print("✅ Authenticated with Google account")

# === Ensure the target directory exists ===
import os
os.makedirs(LOCAL_DIR, exist_ok=True)

# === Sync data from GCS to local ===
import subprocess, shlex

cmd = f'gsutil -m rsync -r "gs://{BUCKET_NAME}/{GCS_PREFIX}" "{LOCAL_DIR}"'
print(f"Running: {cmd}")
subprocess.check_call(shlex.split(cmd))

print(f"✅ Download complete. Files restored to {LOCAL_DIR}")
# !ls -lh "{LOCAL_DIR}"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 23.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-aiplatform 1.121.0 requires google-cloud-storage<3.0.0,>=1.32.0, but you have google-cloud-storage 3.4.1 which is incompatible.
# google-adk 1.16.0 requires google-cloud-storage<3.0.0,>=2.18.0, but you have google-cloud-storage 3.4.1 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# ✅ Authenticated with Google account
# Running: gsutil -m rsync -r "gs://speed_transformer/speed_transformer" "/content/A-SpeedTransformer"
# ✅ Download complete. Files restored to /content/A-SpeedTransformer
# total 200K
# drwxr-xr-x 2 root root 4.0K Oct 26 21:34 data
# drwxr-xr-x 6 root root 4.0K Oct 26 21:31 models
# -rw-r--r-- 1 root root 3.1K Oct 24 02:00 README.md
# -rw-r--r-- 1 root root 187K Oct 24 01:59 SpeedTransformer.ipynb

# %% [markdown]
# ## Appendix H Results & Figure Plotting

# %%
# !python /content/A-SpeedTransformer/models/rule_based/rule_baseline.py \
  --data_path "/content/A-SpeedTransformer/data/geolife_processed.csv" \
  --label_encoder_path "/content/A-SpeedTransformer/models/rule_based/label_encoder.joblib" \
  --out_dir "/content/A-SpeedTransformer/models/rule_based/experiments/rule_geolife" \
  --auto_calibrate
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Collecting traj_ids: 1it [00:00,  4.90it/s]
# Building windows: 1it [00:00,  3.09it/s]
# Building windows: 1it [00:00,  3.84it/s]
# [Rule Baseline] Test Accuracy: 0.0220
#               precision    recall  f1-score   support
#
#         bike     0.0000    0.0000    0.0000         0
#          bus     0.0000    0.0000    0.0000       126
#          car     0.0490    0.0656    0.0561       183
#        train     0.0000    0.0000    0.0000      3856
#         walk     1.0000    0.7961    0.8865       103
#
#     accuracy                         0.0220      4268
#    macro avg     0.2098    0.1723    0.1885      4268
# weighted avg     0.0262    0.0220    0.0238      4268
#
# object address  : 0x7b0d31a30d00
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %%
# !python /content/A-SpeedTransformer/models/rule_based/rule_baseline.py \
  --data_path "/content/A-SpeedTransformer/data/mobis_processed.csv" \
  --label_encoder_path "/content/A-SpeedTransformer/models/rule_based/label_encoder.joblib" \
  --out_dir "/content/A-SpeedTransformer/models/rule_based/experiments/rule_mobis" \
  --auto_calibrate
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.3.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Collecting traj_ids: 1it [00:00,  1.46it/s]
# Building windows: 1it [00:00,  1.20it/s]
# Building windows: 1it [00:00,  1.60it/s]
# [Rule Baseline] Test Accuracy: 0.7127
#               precision    recall  f1-score   support
#
#         bike     0.2019    0.9255    0.3314        94
#          bus     0.0000    0.0000    0.0000        49
#          car     0.8705    0.7894    0.8280       945
#        train     0.0000    0.0000    0.0000       109
#         walk     0.9902    0.7632    0.8620       397
#
#     accuracy                         0.7127      1594
#    macro avg     0.4125    0.4956    0.4043      1594
# weighted avg     0.7746    0.7127    0.7251      1594
#
# [OK] Saved outputs to: /content/A-SpeedTransformer/models/rule_based/experiments/rule_mobis

# %% [markdown]
# ## Appendix I Figure Plotting

# %%
 # !python /content/A-SpeedTransformer/models/run_speedtransformer_rf_visualize_computation.py \
  --root /content/A-SpeedTransformer \
  --do-transformer \
  --do-lstm \
  --do-plot \
  --monitor

# %% [markdown]
# ## Appendix G Results

# %%
# !wget -O /content/SpeedTransformer1.zip https://zenodo.org/records/15535357/files/SpeedTransformer.zip
# !unzip /content/SpeedTransformer1.zip

# %%
# !mv /content/A-SpeedTransformer/data/mobis_processed.csv /content/SpeedTransformer/data/mobis_processed.csv
# !mv /content/A-SpeedTransformer/data/geolife_processed.csv /content/SpeedTransformer/data/geolife_processed.csv
# !mv /content/A-SpeedTransformer/data/miniprogram_balanced.csv /content/SpeedTransformer/data/miniprogram_balanced.csv

# %%
# LSTM on Geolife
# %cd /content/SpeedTransformer/models/lstm
# !python lstm.py --data_path  /content/SpeedTransformer/data/geolife_processed.csv --random_state 1
# %cd /content/

# %%
# LSTM on Mobis
# %cd /content/SpeedTransformer/models/lstm
# !python lstm.py --data_path /content/SpeedTransformer/data/mobis_processed.csv --random_state 316
# %cd /content/

# %%
# SpeedTransformer_v1 on Geolife
# %cd /content/SpeedTransformer/models/transformer
# !python train.py --data_path /content/SpeedTransformer/data/geolife_processed.csv --random_state 316
# %cd /content/

# %%
# SpeedTransformer_v1 on Mobis
# %cd /content/SpeedTransformer/models/transformer
# !python train.py --data_path /content/SpeedTransformer/data/mobis_processed.csv --random_state 1
# %cd /content/

# %%
## Finetuning - Transformer
# %cd /content/SpeedTransformer/models/transformer

# Fine-tune with 2% of data used for training
# !python finetune.py \
  --pretrained_model_path /content/SpeedTransformer/models/transformer/mobis/best_model.pth \
  --data_path /content/SpeedTransformer/data/geolife_processed.csv \
  --label_encoder_path /content/SpeedTransformer/models/transformer/mobis/label_encoder.joblib \
  --test_size 0.7786 \
  --val_size 0.2 \
  --random_state 42
# %cd /content/

# %%
## Finetuning - LSTM
# %cd /content/SpeedTransformer/models/lstm

# Fine-tune with 2% of data used for training
# !python finetune.py \
  --pretrained_model_path /content/SpeedTransformer/models/lstm/mobis/best_model.pth \
  --data_path /content/SpeedTransformer/data/geolife_processed.csv \
  --scaler_path /content/SpeedTransformer/models/lstm/mobis/scaler.joblib \
  --label_encoder_path /content/SpeedTransformer/models/lstm/mobis/label_encoder.joblib \
  --test_size 0.7893 \
  --val_size 0.2 \
  --random_state 42
# %cd /content/

# %%
## Miniprogram with pre-trained Transformer
# %cd SpeedTransformer/models/transformer

# Fine-tune with 40% of data used for training
# !python finetune.py \
  --pretrained_model_path /content/SpeedTransformer/models/transformer/mobis/best_model.pth \
  --data_path /content/SpeedTransformer/data/miniprogram_balanced.csv \
  --label_encoder_path /content/SpeedTransformer/models/transformer/mobis/label_encoder.joblib \
  --test_size 0.55 \
  --val_size 0.2 \
  --random_state 42

# Return to root directory
# %cd /content/

# %%
## Miniprogram with pre-trained LSTM
# %cd SpeedTransformer/models/lstm

# Fine-tune with 40% of data used for training
# !python finetune.py \
  --pretrained_model_path /content/SpeedTransformer/models/lstm/mobis/best_model.pth \
  --data_path /content/SpeedTransformer/data/miniprogram_balanced.csv \
  --label_encoder_path /content/SpeedTransformer/models/lstm/mobis/label_encoder.joblib \
  --scaler_path /content/SpeedTransformer/models/lstm/mobis/scaler.joblib \
  --test_size 0.55 \
  --val_size 0.2 \
  --random_state 42

# Return to root directory
# %cd /content/
